# %%
# By importing important libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading our data, it is in excel formate with different sheets
kpmg=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx")
kpmg
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
#     Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# ...

# %%
# Here we load Transaction sheet from our data
trans=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name="Transactions")
trans
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
trans["product_first_sold_date"]="product_first_sold_price"

# %%
trans["list_price"].max()
# Out:
# 2091.47

# %%
trans["product_first_sold_date"].max()
# Out:
# 'product_first_sold_price'

# %%
trans["standard_cost"].max()
# Out:
# 1759.85

# %%
trans.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
trans.shape
# Out:
# (20000, 13)

# %%
trans.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date      0
# dtype: int64

# %%
trans.duplicated().sum()
# Out:
# 0

# %%
trans.descri
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %%
# by Loading Customer Demographic sheet from excel.
custdem=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="CustomerDemographic")
custdem
# Out:
# C:\Users\Al Rehman Laptop\AppData\Local\Temp\ipykernel_2368\291152352.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   custdem=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="CustomerDemographic")
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# ...

# %%
# Working on Customer Demographic Data.

# %%
custdem.drop("default",axis=1, inplace=True)

# %%
custdem.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
f=custdem[custdem["gender"]=="Male"]
f.replace("M")
# Out:
#       customer_id first_name  last_name gender  \
# 1               2        Eli    Bockman   Male
# 2               3      Arlin     Dearle   Male
# 3               4     Talbot        NaN   Male
# 5               6       Curr  Duckhouse   Male
# 7               8        Rod      Inder   Male
# ...           ...        ...        ...    ...
# 3990         3991      Rolph   Sweetnam   Male
# 3991         3992    Germain    Tireman   Male
# 3994         3995      Rusty     Iapico   Male
# 3998         3999  Patrizius        NaN   Male
# 3999         4000      Kippy    Oldland   Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 3                                      33 1961-10-03
# 5                                      35 1966-09-16
# 7                                      31 1962-03-30
# ...                                   ...        ...
# ...

# %%
m=custdem[custdem["gender"]=="Female"]
m.replace("F")
# Out:
#       customer_id      first_name last_name  gender  \
# 4               5  Sheila-kathryn    Calton  Female
# 6               7            Fina    Merali  Female
# 8               9            Mala      Lind  Female
# 9              10        Fiorenze   Birdall  Female
# 13             14        Rayshell  Kitteman  Female
# ...           ...             ...       ...     ...
# 3987         3988       Ammamaria  Ashburne  Female
# 3992         3993            Andi   Dumelow  Female
# 3993         3994         Stephie     Byars  Female
# 3995         3996         Rosalia  Halgarth  Female
# 3996         3997          Blanch    Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 4                                      56 1977-05-13
# 6                                       6 1976-02-23
# 8                                      97 1973-03-10
# 9                                      49 1988-10-11
# 13                                     85 1983-03-25
# ...

# %%
custdem.shape
# Out:
# (4000, 12)

# %%
custdem.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
custdem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  owns_car                             4000 non-null   object
# ...

# %%
custdem.duplicated().sum()
# Out:
# 0

# %%
custdem.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
# Uploading Customer Address sheet

# %%
custadrs=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", sheet_name="CustomerAddress")
custadrs
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
custadrs.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
custadrs.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
custadrs.duplicated().sum()
# Out:
# 0

# %%
custadrs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
# By uploading new customer list

# %%
new_cust=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="NewCustomerList")
new_cust
# Out:
# C:\Users\Al Rehman Laptop\AppData\Local\Temp\ipykernel_2368\1556089053.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   new_cust=pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx",sheet_name="NewCustomerList")
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# ...

# %%
new_cust.drop(new_cust.columns[[16,17,18,19,20]],axis=1, inplace=True)

# %%
new_cust
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
new_cust["Value"].max()
# Out:
# 1.71875

# %%
new_cust[new_cust["Value"]==1.71875]
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
#
#          DOB               job_title job_industry_category     wealth_segment  \
# 0 1957-07-12         General Manager         Manufacturing      Mass Customer
# 1 1970-03-22     Structural Engineer              Property      Mass Customer
# 2 1974-08-28  Senior Cost Accountant    Financial Services  Affluent Customer
#
#   deceased_indicator owns_car  tenure              address  postcode state  \
# 0                  N      Yes      14     45 Shopko Center      4500   QLD
# 1                  N       No      16    14 Mccormick Park      2113   NSW
# 2                  N       No      10  5 Colorado Crossing      3505   VIC
#
#      country  property_valuation  Rank    Value
# ...

# %%
# We have to combine all three datasets to get more information on the basis of common column

# %%
data=trans.merge(custdem, on = "customer_id")
data.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    gender  past_3_years_bike_related_purchases        DOB  \
# ...

# %%
merg=data.merge(custadrs, on = "customer_id")
merg.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
# ...

# %%
merg.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
merg[["first_name","last_name","property_valuation"]].max()
# Out:
# C:\Users\Al Rehman Laptop\AppData\Local\Temp\ipykernel_2368\3348529341.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   merg[["first_name","last_name","property_valuation"]].max()
# first_name            Zulema
# property_valuation        12
# dtype: object

# %%
merg.shape
# Out:
# (19968, 30)

# %%
merg["property_valuation"].max()
# Out:
# 12

# %%
merg[merg["property_valuation"]==12]["brand"]
# Out:
# 164      Giant Bicycles
# 165            WeareA2B
# 166       Trek Bicycles
# 167            WeareA2B
# 168      Giant Bicycles
#               ...
# 19915    Giant Bicycles
# 19916     Trek Bicycles
# 19917     Trek Bicycles
# 19918          WeareA2B
# 19919    Giant Bicycles
# Name: brand, Length: 971, dtype: object

# %%
merg.groupby("brand").sum()
# Out:
#                 transaction_id  product_id  customer_id  online_order  \
# brand
# Giant Bicycles        32427923      147075      5775196        1640.0
# Norco Bicycles        28733579      150732      5078723        1417.0
# OHM Cycles            30569890      149956      5329146        1560.0
# Solex                 43006884      170472      7350665        2043.0
# Trek Bicycles         29967332      106420      5184660        1457.0
# WeareA2B              32855960      181213      5709378        1612.0
#
#                 list_price  standard_cost  \
# brand
# Giant Bicycles  4087286.32     2514861.39
# Norco Bicycles  2653270.18     1787484.02
# OHM Cycles      2990291.79     1509409.37
# Solex           4492867.78     2080969.09
# Trek Bicycles   3530928.30     1695851.83
# WeareA2B        4154701.36     1407012.63
#
#                 past_3_years_bike_related_purchases   tenure  postcode  \
# brand
# Giant Bicycles                               161729  34638.0   9913300
# ...

# %%
merg[merg["property_valuation"]==12].shape
# Out:
# (971, 30)

# %%
merg[merg["property_valuation"]==12]["brand"].value_counts(ascending=False)
# Out:
# Solex             206
# OHM Cycles        160
# Giant Bicycles    156
# Trek Bicycles     156
# WeareA2B          148
# Norco Bicycles    137
# Name: brand, dtype: int64

# %%
# Also combine new_customer dataset with above all

# %%
sf=merg.merge(new_cust, on = "first_name")
sf.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               9          67         1305       2017-08-10           0.0
# 1              48          81         1305       2017-06-10           1.0
# 2            1803          21         1305       2017-04-22           0.0
# 3            5048           0         1305       2017-02-13           0.0
# 4            9526          90         1305       2017-04-07           1.0
#
#   order_status       brand product_line product_class product_size  ...  \
# 0     Approved       Solex     Standard        medium        large  ...
# 1     Approved       Solex     Standard        medium       medium  ...
# 2     Approved    WeareA2B      Touring        medium       medium  ...
# 3     Approved  OHM Cycles     Standard          high       medium  ...
# 4     Approved       Solex     Standard           low       medium  ...
#
#    state_y  country_y property_valuation_y Unnamed: 16 Unnamed: 17  \
# ...

# %%
sf.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'first_name', 'last_name_x', 'gender_x',
#        'past_3_years_bike_related_purchases_x', 'DOB_x', 'job_title_x',
#        'job_industry_category_x', 'wealth_segment_x', 'deceased_indicator_x',
#        'owns_car_x', 'tenure_x', 'address_x', 'postcode_x', 'state_x',
#        'country_x', 'property_valuation_x', 'last_name_y', 'gender_y',
#        'past_3_years_bike_related_purchases_y', 'DOB_y', 'job_title_y',
#        'job_industry_category_y', 'wealth_segment_y', 'deceased_indicator_y',
#        'owns_car_y', 'tenure_y', 'address_y', 'postcode_y', 'state_y',
#        'country_y', 'property_valuation_y', 'Rank', 'Value'],
#       dtype='object')

# %%
sf["Rank"].max()
# Out:
# 1000

# %%
sf["Rank"].min()
# Out:
# 1

# %%
k=sf[sf["Rank"]==1000]
k
# Out:
#       transaction_id  product_id  customer_id transaction_date  online_order  \
# 1442            2312           0         3325       2017-11-15           1.0
# 1443            3775          30         3325       2017-08-12           1.0
# 1444            6101          96         3325       2017-09-04           0.0
# 1445            7019          77         3325       2017-02-18           0.0
# 1446            9176           0         3325       2017-07-08           1.0
#
#      order_status           brand product_line product_class product_size  \
# 1442     Approved  Norco Bicycles         Road        medium       medium
# 1443     Approved      OHM Cycles     Standard        medium       medium
# 1444     Approved  Giant Bicycles     Standard        medium        large
# 1445     Approved        WeareA2B     Standard        medium       medium
# 1446     Approved   Trek Bicycles         Road        medium       medium
#
# ...

# %%
sf.drop_duplicates("customer_id")
# Out:
#       transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                  9          67         1305       2017-08-10           0.0
# 5                 12          61         2783       2017-01-05           1.0
# 16                17          79         2426       2017-04-03           0.0
# 21                29          72         3368       2017-10-13           1.0
# 31                31          88         2810       2017-09-05           1.0
# ...              ...         ...          ...              ...           ...
# 2312           10404          92         3341       2017-06-19           1.0
# 2316           11304          87         3006       2017-07-28           1.0
# 2320           11309          23         2437       2017-06-15           1.0
# 2322           14625          86         1734       2017-12-05           1.0
# 2324           15838          65         3041       2017-08-28           1.0
#
# ...

# %%
sf.shape
# Out:
# (2326, 46)

# %%
sf["last_name_x"]
# Out:
# 0           Gentiry
# 1           Gentiry
# 2           Gentiry
# 3           Gentiry
# 4           Gentiry
#            ...
# 2321    Cressingham
# 2322       Cullerne
# 2323       Cullerne
# 2324        Kingaby
# 2325        Kingaby
# Name: last_name_x, Length: 2326, dtype: object

# %%
sf.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date', 'first_name', 'last_name_x', 'gender_x',
#        'past_3_years_bike_related_purchases_x', 'DOB_x', 'job_title_x',
#        'job_industry_category_x', 'wealth_segment_x', 'deceased_indicator_x',
#        'owns_car_x', 'tenure_x', 'address_x', 'postcode_x', 'state_x',
#        'country_x', 'property_valuation_x', 'last_name_y', 'gender_y',
#        'past_3_years_bike_related_purchases_y', 'DOB_y', 'job_title_y',
#        'job_industry_category_y', 'wealth_segment_y', 'deceased_indicator_y',
#        'owns_car_y', 'tenure_y', 'address_y', 'postcode_y', 'state_y',
#        'country_y', 'property_valuation_y', 'Rank', 'Value'],
#       dtype='object')

# %%
sf["last_name_y"]
# Out:
# 0            Ackery
# 1            Ackery
# 2            Ackery
# 3            Ackery
# 4            Ackery
#            ...
# 2321            NaN
# 2322    Saundercock
# 2323    Saundercock
# 2324       Godleman
# 2325       Godleman
# Name: last_name_y, Length: 2326, dtype: object

# %% [markdown]
# # Visualization of data

# %%
# We are ploting some usefule graphs to extract insights of data
